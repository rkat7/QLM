# %% [markdown]
# <a href="https://colab.research.google.com/github/rkat7/QLM/blob/colab-run/QLM_colab_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b colab-run --single-branch https://github.com/rkat7/QLM.git
# Out:
# Cloning into 'QLM'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 7), reused 24 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 19.51 KiB | 9.75 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !git pull origin colab-run
# Out:
# From https://github.com/rkat7/QLM
#  * branch            colab-run  -> FETCH_HEAD
# Already up to date.

# %%
# %cd QLM
# !pip install -r requirements.txt
# Out:
# /content/QLM
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/QLM
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: qlm
#     Found existing installation: qlm 0.1
#     Uninstalling qlm-0.1:
#       Successfully uninstalled qlm-0.1
#   Running setup.py develop for qlm
# ...

# %%
import os

os.environ['QLMPROJDIR']='/content/QLM'

# %%
from huggingface_hub import login
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
login(HF_TOKEN)

# %%
# %pwd
# Out:
# '/content/QLM'

# %%
# !python3 benchmarks/basic_test.py
# Out:
# 2025-09-16 21:14:40.807213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758057280.827734    4670 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758057280.833862    4670 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758057280.849465    4670 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !nvidia-smi
# Out:
# Tue Sep 16 20:58:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
